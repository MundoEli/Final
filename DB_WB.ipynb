# %% [markdown]
# <a href="https://colab.research.google.com/github/MundoEli/Final/blob/main/DB_WB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

folder_path = '/content/drive/My Drive/'

files = os.listdir(folder_path)

for file in files:
    print(f'{folder_path}{file}')
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /content/drive/My Drive/Classroom
# /content/drive/My Drive/Munduzbaev Elibek.gsheet
# /content/drive/My Drive/Untitled document.gdoc
# /content/drive/My Drive/Elibek cover-letter.gdoc
# /content/drive/My Drive/Computer Hardware Technology PowerPoint Templates.gslides
# /content/drive/My Drive/Untitled presentation.gslides
# /content/drive/My Drive/Computer Hardware Technology PowerPoint Templates.pptx - Column chart 1.gsheet
# /content/drive/My Drive/Computer Hardware Technology PowerPoint Templates.pptx - Line chart 2.gsheet
# /content/drive/My Drive/Computer Hardware Technology PowerPoint Templates.pptx - Pie chart 3.gsheet
# /content/drive/My Drive/Computer Hardware Technology PowerPoint Templates.pptx
# /content/drive/My Drive/render.png
# /content/drive/My Drive/Microsoft Quiz.gform
# /content/drive/My Drive/CSC22ElI.blend
# /content/drive/My Drive/DiceT.blend
# /content/drive/My Drive/dice-render.png
# ...

# %%
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from IPython.display import display

file_path = '/content/drive/My Drive/amazon database Akram.xlsx'

try:
    df = pd.read_excel(file_path, engine='openpyxl')


    display(df.head(10))

except Exception as e:
    print(f"Ошибка при загрузке файла с движком openpyxl: {e}")
# Out:
#                                      Название товара        Цена  \
# 0  jumper 16 Inch Laptop Computer, 12GB RAM 640GB...   $1,199.99
# 1  Dual Screen Laptop Computer 14" Dual Screen la...  $1,499.99
# 2  CHITA Power Recliner Chair Swivel Glider, FSC ...     $539.49
# 3  The Simplest Baby Book in the World: The Illus...      $24.95
# 4  Hefty Ultra Strong 13 Gallon Trash Bags, Tall ...      $15.99
# 5  Liquid Vacuum Sealer Machine, 90Kpa Vacuum Sea...     $149.99
# 6  INIU Portable Charger, Slimmest 10000mAh 5V/3A...      $12.90
# 7  O-Cedar EasyWring Microfiber Spin Mop, Bucket ...       39.99
# 8  Utopia Bedding Throw Pillows (Set of 4, White)...      $29.99
# 9  Café Affetto Automatic Espresso Machine + Milk...     $629.00
#
#   Продажи за месяц Рейтинг и общее количество  Общее количество отзывов   \
# 0              50+                    4.5 (21)                      (21)
# 1             200+                   4.4 (131)                     (131)
# ...

# %%
top_10_expensive = df.sort_values(by='Цена', ascending=False).head(10)
display(top_10_expensive[['Название товара', 'Цена']])
# Out:
#                                        Название товара     Цена
# 1    Dual Screen Laptop Computer 14" Dual Screen la...  1499.99
# 190  Dual Screen Laptop Computer 14" Dual Screen la...  1499.99
# 68   dreame L30 Ultra Robot Vacuum and Mop, 136°F H...  1469.31
# 0    jumper 16 Inch Laptop Computer, 12GB RAM 640GB...  1199.99
# 189  jumper 16 Inch Laptop Computer, 12GB RAM 640GB...  1199.99
# 26   Dell OptiPlex Computer Desktop PC, Intel Core ...   999.99
# 34   HTC Vive Focus Vision — Mixed Reality and PC V...   999.00
# 9    Café Affetto Automatic Espresso Machine + Milk...   629.00
# 180  Acer Aspire TC-1785-UA92 Desktop | Intel Core ...   584.47
# 179  HP ProDesk 400 G9 Mini Business Desktop, 13th ...   546.00

# %%
top_10_low_prise = df.sort_values(by='Цена', ascending=True).head(10)
display(top_10_expensive[['Название товара', 'Цена']])
# Out:
#                                        Название товара     Цена
# 1    Dual Screen Laptop Computer 14" Dual Screen la...  1499.99
# 190  Dual Screen Laptop Computer 14" Dual Screen la...  1499.99
# 68   dreame L30 Ultra Robot Vacuum and Mop, 136°F H...  1469.31
# 0    jumper 16 Inch Laptop Computer, 12GB RAM 640GB...  1199.99
# 189  jumper 16 Inch Laptop Computer, 12GB RAM 640GB...  1199.99
# 26   Dell OptiPlex Computer Desktop PC, Intel Core ...   999.99
# 34   HTC Vive Focus Vision — Mixed Reality and PC V...   999.00
# 9    Café Affetto Automatic Espresso Machine + Milk...   629.00
# 180  Acer Aspire TC-1785-UA92 Desktop | Intel Core ...   584.47
# 179  HP ProDesk 400 G9 Mini Business Desktop, 13th ...   546.00

# %%
top_10_sales = df.sort_values(by='Продажи за месяц', ascending=False).head(10)
display(top_10_sales[['Название товара', 'Цена', 'Продажи за месяц']])
# Out:
#                                        Название товара    Цена  \
# 101  Two Pocket Folders, PANDRI 100 Pack 2 Pocket F...   33.99
# 83   GermGuardian HEPA Air Purifier for Home, Large...  189.99
# 2    CHITA Power Recliner Chair Swivel Glider, FSC ...  539.49
# 92   Ditucu Cute Capybara Plush Wear Strawberry Hat...   26.99
# 174  Dell OptiPlex 7070 SFF Desktop Computer PC, In...  472.98
# 100  Amazon Basics Large Extended Computer Rectangu...   17.52
# 40   Water Bottle Pump 5 Gallon Water bottle dispen...   18.99
# 124  Headset wtih Mic, USB Headset with Microphone ...   19.99
# 130  SHOWPIN 122 in 1 Precision Computer Screwdrive...   21.99
# 151  Maxone 320GB Ultra Slim Portable External Hard...   28.59
#
#      Продажи за месяц
# 101             800.0
# 83              800.0
# 2               600.0
# 92              600.0
# 174             500.0
# 100             500.0
# 40              500.0
# 124             500.0
# 130             500.0
# 151             500.0

# %%
top_10_worst_sales = df.sort_values(by='Продажи за месяц', ascending=True).head(10)
display(top_10_sales[['Название товара', 'Цена', 'Продажи за месяц']])
# Out:
#                                        Название товара    Цена  \
# 155  9x12 Area Rugs, Machine Washable Area Rugs for...  157.99
# 153  Glamativity Large Kitchen Metal Name Sign Wall...   39.99
# 154  TenXVI Designs 18"x22" Magnetic Chalkboard Sig...   44.99
# 178  JINGCHENGMEI 6U Desktop Network Rack 19 inches...   44.99
# 37   Sonic Prime 5" Articulated Action Figure - Sha...   28.60
# 49   Ahopegarden Indoor Garden Hydroponics Growing ...   69.99
# 27   GMKtec Mini PC Intel N150 Windows 11 Pro (3.6G...  249.99
# 50   SOLIGT 60 Cell Seed Starter Kit with Grow Ligh...   49.99
# 76   CIRCLE JOY Electric Pepper Grinder Stainless S...   21.99
# 77   Beckham Hotel Collection Queen Size Hybrid Mat...  125.99
#
#      Продажи за месяц
# 155               0.0
# 153               0.0
# 154               0.0
# 178               0.0
# 37                1.0
# 49                1.0
# 27                1.0
# 50                1.0
# 76                1.0
# 77                1.0

# %%
price_counts = df.groupby('Цена')['Цена'].count().reset_index(name='Количество')
popular_prices = price_counts.sort_values(by='Количество', ascending=False)
print(popular_prices.head(10))
# Out:
#       Цена  Количество
# 64   69.99          10
# 43   29.99           7
# 24   19.99           6
# 99  249.99           6
# 88  199.99           6
# 53   39.99           5
# 33   24.99           5
# 36   26.99           4
# 14   15.99           4
# 13   14.99           4

# %%
price_counts = df.groupby('Цена')['Цена'].count().reset_index(name='Количество')
popular_prices = price_counts.sort_values(by='Количество', ascending=True)
print(popular_prices.head(10))
# Out:
#       Цена  Количество
# 0     5.99           1
# 86  196.79           1
# 85  196.35           1
# 83  185.19           1
# 82  157.99           1
# 81  154.99           1
# 80  151.46           1
# 79  149.99           1
# 78  147.98           1
# 76  139.98           1

# %%
df['Popularity_Price_Ratio'] = df['Продажи за месяц'] / df['Цена']
df_sorted = df.sort_values(by=['Popularity_Price_Ratio'], ascending=False)
best_product = df_sorted.iloc[0]
print(best_product[['Название товара', 'Цена', 'Продажи за месяц']])
# Out:
# Название товара     Amazon Basics Large Extended Computer Rectangu...
# Цена                                                            17.52
# Продажи за месяц                                                500.0
# Name: 100, dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.figure(figsize=(10, 6))
plt.title('Точечный график цен')
sns.scatterplot(x = df['Название товара'], y = df['Цена'])
# Out:
# <Axes: title={'center': 'Точечный график цен'}, xlabel='Название товара', ylabel='Цена'>
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.figure(figsize=(10, 6))
plt.title('Точечный график популярности')
sns.scatterplot(x = df['Название товара'], y = df['Рейтинг '])
# Out:
# <Axes: title={'center': 'Точечный график популярности'}, xlabel='Название товара', ylabel='Рейтинг '>
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
